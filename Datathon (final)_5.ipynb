# %%
import pandas as pd             # data analysis
import numpy as np              # linear algebra + array handling
import sklearn                  # machine learning
import matplotlib.pyplot as plt # visualization
import seaborn as sns  
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
sns.set_palette('deep')
plt.rc('font', family='NanumGothic')

# %%
mat_data = pd.read_csv('student-mat.csv')
por_data = pd.read_csv('student-por.csv')
df = pd.concat([mat_data,por_data])
mat_data['subject'] = 'mat'
por_data['subject'] = 'por'
df = pd.concat([mat_data,por_data])

# %% [markdown]
# # 1. Failures

# %%
df["failures"].value_counts()
plt.pie(df["failures"].value_counts().values, labels=df["failures"].value_counts().index, autopct="%d%%")
plt.title('F학점에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'failures',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('F학점에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'failures',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('F학점에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="failures", y="G1")
plt.title('F학점에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="failures", y="G2")
plt.title('F학점에 따른 G2성적 분포')
plt.show()

# %% [markdown]
# # 2. Romantic

# %%
df["romantic"].value_counts()
plt.pie(df["romantic"].value_counts().values, labels=df["romantic"].value_counts().index, autopct="%d%%")
plt.title('애정관계여부에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'romantic',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('애정관계여부에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'romantic',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('애정관계여부에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="romantic", y="G1")
plt.title('애정관계여부에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="romantic", y="G2")
plt.title('애정관계여부에 따른 G2성적 분포')
plt.show()

df_by_group = df.groupby(['romantic'])['G1'].mean().reset_index()
sns.barplot(x='romantic', y='G1', data=df_by_group)
plt.title('애정관계여부에 따른 G1 평균 성적 분포')
plt.show()

df_by_group = df.groupby(['romantic'])['G2'].mean().reset_index()
sns.barplot(x='romantic', y='G2', data=df_by_group)
plt.title('애정관계여부에 따른 G2 평균 성적 분포')
plt.show()

sns.scatterplot(data=df, x="G1", y="G2", hue="romantic")
plt.title('애정관계여부에 따른 G1,G2성적 분포')
plt.show()

# %% [markdown]
# # 3. Dalc

# %%
df["Dalc"].value_counts()
plt.pie(df["Dalc"].value_counts().values, labels=df["Dalc"].value_counts().index, autopct="%d%%")
plt.title('주중음주정도에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Dalc',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('주중음주정도에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Dalc',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('주중음주정도에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="Dalc", y="G1")
plt.title('주중음주정도에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="Dalc", y="G2")
plt.title('주중음주정도에 따른 G2성적 분포')
plt.show()

df_by_group = df.groupby(['Dalc'])['G1'].mean().reset_index()
sns.barplot(x='Dalc', y='G1', data=df_by_group)
plt.title('주중음주정도에 따른 G1 평균 성적 분포')
plt.show()

df_by_group = df.groupby(['Dalc'])['G2'].mean().reset_index()
sns.barplot(x='Dalc', y='G2', data=df_by_group)
plt.title('주중음주정도에 따른 G2 평균 성적 분포')
plt.show()

ax =sns.scatterplot(data=df, x="Dalc", y="G2"),sns.barplot(x='Dalc', y='G2', data=df_by_group, alpha = 0.5)
plt.show()

# sns.scatterplot(data=df, x="G1", y="G2", hue="romantic")
# plt.title('애정관계여부에 따른 G1,G2성적 분포')
# plt.show()

# %%
print(df.groupby(by=['Dalc'])['G1'].mean())
print(df.groupby(by=['Dalc'])['G2'].mean())
# Out:
# Dalc
# 1    11.492435
# 2    10.790816
# 3    10.492754
# 4     9.884615
# 5     9.846154
# Name: G1, dtype: float64
# Dalc
# 1    11.536451
# 2    10.719388
# 3    10.666667
# 4     9.576923
# 5    10.307692
# Name: G2, dtype: float64

# %% [markdown]
# # 4. Walc

# %%
df["Walc"].value_counts()
plt.pie(df["Walc"].value_counts().values, labels=df["Walc"].value_counts().index, autopct="%d%%")
plt.title('주말음주정도에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Walc',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('주말음주정도에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Walc',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('주말음주정도에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="Walc", y="G1")
plt.title('주말음주정도에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="Walc", y="G2")
plt.title('주말음주정도에 따른 G2성적 분포')
plt.show()

df_by_group = df.groupby(['Walc'])['G1'].mean().reset_index()
sns.barplot(x='Walc', y='G1', data=df_by_group)
plt.title('주말음주정도에 따른 G1 평균 성적 분포')
plt.show()

df_by_group = df.groupby(['Walc'])['G2'].mean().reset_index()
sns.barplot(x='Walc', y='G2', data=df_by_group)
plt.title('주말음주정도에 따른 G2 평균 성적 분포')
plt.show()

# %%
print(df.groupby(by=['Walc'])['G1'].mean())
print(df.groupby(by=['Walc'])['G2'].mean())
# Out:
# Walc
# 1    11.494975
# 2    11.574468
# 3    11.160000
# 4    10.405797
# 5    10.191781
# Name: G1, dtype: float64
# Walc
# 1    11.610553
# 2    11.382979
# 3    11.265000
# 4    10.376812
# 5    10.410959
# Name: G2, dtype: float64

# %% [markdown]
# # 5. Fedu

# %%
df["Fedu"].value_counts()
plt.pie(df["Fedu"].value_counts().values, labels=df["Fedu"].value_counts().index, autopct="%d%%")
plt.title('아버지 교육수준에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Fedu',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('아버지 교육수준에  따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Fedu',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('아버지 교육수준에  따른 과목별 전체학생수 분포')
plt.show()


df_by_group = df.groupby(['Fedu'])['G1'].mean().reset_index()
ax = sns.violinplot(data=df, x="Fedu", y="G1")
plt.title('아버지 교육수준에 따른 G1 평균성적 분포')
plt.show()
ax = sns.violinplot(data=df, x="Fedu", y="G1"),sns.barplot(x='Fedu', y='G1', data=df_by_group, alpha = 0.5)
plt.title('아버지 교육수준에 따른 G1 평균성적 분포')
plt.show()


df_by_group = df.groupby(['Fedu'])['G2'].mean().reset_index()
ax = sns.violinplot(data=df, x="Fedu", y="G2")
plt.title('아버지 교육수준에 따른 G2 평균성적 분포')
plt.show()
ax = sns.violinplot(data=df, x="Fedu", y="G2"),sns.barplot(x='Fedu', y='G2', data=df_by_group, alpha = 0.5)
plt.title('아버지 교육수준에 따른 G2 평균성적 분포')
plt.show()

# %% [markdown]
# # 6. Medu

# %%
df["Medu"].value_counts()
plt.pie(df["Medu"].value_counts().values, labels=df["Medu"].value_counts().index, autopct="%d%%")
plt.title('어머니 교육수준에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Medu',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('어머니 교육수준에  따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Medu',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('어머니 교육수준에  따른 과목별 전체학생수 분포')
plt.show()

df_by_group = df.groupby(['Medu'])['G1'].mean().reset_index()
ax = sns.violinplot(data=df, x="Medu", y="G1")
plt.title('어머니 교육수준에 따른 G1 평균성적 분포')
plt.show()
ax = sns.violinplot(data=df, x="Medu", y="G1"),sns.barplot(x='Medu', y='G1', data=df_by_group, alpha = 0.5)
plt.title('어머니 교육수준에 따른 G1 평균성적 분포')
plt.show()


df_by_group = df.groupby(['Medu'])['G2'].mean().reset_index()
ax = sns.violinplot(data=df, x="Medu", y="G2")
plt.title('어머니 교육수준에 따른 G2 평균성적 분포')
plt.show()
ax = sns.violinplot(data=df, x="Medu", y="G2"),sns.barplot(x='Medu', y='G2', data=df_by_group, alpha = 0.5)
plt.title('어머니 교육수준에 따른 G2 평균성적 분포')
plt.show()

# %% [markdown]
# # 7. famrel

# %%
df["famrel"].value_counts()
plt.pie(df["famrel"].value_counts().values, labels=df["famrel"].value_counts().index, autopct="%d%%")
plt.title('가족간 유대관계에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'famrel',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('가족간 유대관계에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'famrel',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('가족간 유대관계에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="famrel", y="G1")
plt.title('가족간 유대관계에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="famrel", y="G2")
plt.title('가족간 유대관계에 따른 G2성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="famrel", y="G2")
plt.title('가족간 유대관계에 따른 G2성적 분포')
plt.show()

df_by_group = df.groupby(['famrel'])['G1'].mean().reset_index()
sns.barplot(x='famrel', y='G1', data=df_by_group)
plt.title('가족간 유대관계에 따른 G1 평균 성적 분포')
plt.show()

df_by_group = df.groupby(['famrel'])['G2'].mean().reset_index()
sns.barplot(x='famrel', y='G2', data=df_by_group)
plt.title('가족간 유대관계에 따른 G2 평균 성적 분포')
plt.show()

sns.scatterplot(data=df, x="G1", y="G2", hue="famrel")
plt.title('가족간 유대관계에 따른 G1,G2성적 분포')
plt.show()

# %% [markdown]
# # 8. guardian

# %%
df["guardian"].value_counts()
plt.pie(df["guardian"].value_counts().values, labels=df["guardian"].value_counts().index, autopct="%d%%")
plt.title('주 보호자에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'guardian',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('주 보호자에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'guardian',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('주 보호자에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="guardian", y="G1")
plt.title('주 보호자에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="guardian", y="G2")
plt.title('주 보호자에 따른 G2성적 분포')
plt.show()

df_by_group = df.groupby(['guardian'])['G1'].mean().reset_index()
sns.barplot(x='guardian', y='G1', data=df_by_group)
plt.title('주 보호자에 따른 G1 평균 성적 분포')
plt.show()

df_by_group = df.groupby(['guardian'])['G2'].mean().reset_index()
sns.barplot(x='guardian', y='G2', data=df_by_group)
plt.title('주 보호자에 따른 G2 평균 성적 분포')
plt.show()

sns.scatterplot(data=df, x="G1", y="G2", hue="guardian")
plt.title('주 보호자에 따른 G1,G2성적 분포')
plt.show()

# %% [markdown]
# # 9. Fjob

# %%
df["Fjob"].value_counts()
plt.pie(df["Fjob"].value_counts().values, labels=df["Fjob"].value_counts().index, autopct="%d%%")
plt.title('아버지 직업에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Fjob',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('아버지 직업에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Fjob',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('아버지 직업에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="Fjob", y="G1")
plt.title('아버지 직업에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="Fjob", y="G2")
plt.title('아버지 직업에 따른 G2성적 분포')
plt.show()

df_by_group = df.groupby(['Fjob'])['G1'].mean().reset_index()
sns.barplot(x='Fjob', y='G1', data=df_by_group)
plt.title('아버지 직업에 따른 G1 평균 성적 분포')
plt.show()


ax = sns.violinplot(data=df, x="Fjob", y="G1"),sns.barplot(x='Fjob', y='G1', data=df_by_group, alpha = 0.5)
plt.title('아버지 직업에 따른 G1성적 분포')
plt.show()

df_by_group = df.groupby(['Fjob'])['G2'].mean().reset_index()
sns.barplot(x='Fjob', y='G2', data=df_by_group)
plt.title('아버지 직업에 따른 G2 평균 성적 분포')
plt.show()


ax = sns.violinplot(data=df, x="Fjob", y="G2"),sns.barplot(x='Fjob', y='G2', data=df_by_group, alpha = 0.5)
plt.title('아버지 직업에 따른 G2성적 분포')
plt.show()

# %% [markdown]
# # 10. Mjob

# %%
df["Mjob"].value_counts()
plt.pie(df["Fjob"].value_counts().values, labels=df["Mjob"].value_counts().index, autopct="%d%%")
plt.title('어머니 직업에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Mjob',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('어머니 직업에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'Mjob',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('어머니 직업에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="Mjob", y="G1")
plt.title('어머니 직업에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="Mjob", y="G2")
plt.title('어머니 직업에 따른 G2성적 분포')
plt.show()

df_by_group = df.groupby(['Mjob'])['G1'].mean().reset_index()
sns.barplot(x='Mjob', y='G1', data=df_by_group)
plt.title('어머니 직업에 따른 G1 평균 성적 분포')
plt.show()
ax = sns.violinplot(data=df, x="Mjob", y="G1"),sns.barplot(x='Mjob', y='G1', data=df_by_group, alpha = 0.5)
plt.title('어머니 직업에 따른 G1성적 분포')
plt.show()

df_by_group = df.groupby(['Mjob'])['G2'].mean().reset_index()
sns.barplot(x='Mjob', y='G2', data=df_by_group)
plt.title('어머니 직업에 따른 G2 평균 성적 분포')
plt.show()
ax = sns.violinplot(data=df, x="Mjob", y="G2"),sns.barplot(x='Mjob', y='G2', data=df_by_group, alpha = 0.5)
plt.title('어머니 직업에 따른 G2성적 분포')
plt.show()

# %% [markdown]
# # 11. studytime

# %%
df["studytime"].value_counts()
plt.pie(df["studytime"].value_counts().values, labels=df["studytime"].value_counts().index, autopct="%d%%")
plt.title('공부시간에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'studytime',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('공부시간에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'studytime',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('공부시간에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="studytime", y="G1")
plt.title('공부시간에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="studytime", y="G2")
plt.title('공부시간에 따른 G2성적 분포')
plt.show()

# %% [markdown]
# # 12. paid

# %%
df["paid"].value_counts()
plt.pie(df["paid"].value_counts().values, labels=df["paid"].value_counts().index, autopct="%d%%")
plt.title('복수전공 여부에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'paid',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('복수전공 여부에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'paid',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('복수전공 여부에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="paid", y="G1")
plt.title('복수전공 여부에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="paid", y="G2")
plt.title('복수전공 여부에 따른 G2성적 분포')
plt.show()

# %% [markdown]
# # 13. school

# %%
df["school"].value_counts()
plt.pie(df["school"].value_counts().values, labels=df["school"].value_counts().index, autopct="%d%%")
plt.title('학교에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'school',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('학교에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'school',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('학교에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="school", y="G1")
plt.title('학교에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="school", y="G2")
plt.title('학교에 따른 G2성적 분포')
plt.show()

sns.scatterplot(data=df, x="G1", y="G2", hue="school")
plt.title('학교에 따른 G1,G2성적 분포')
plt.show()

# %% [markdown]
# # 14. address

# %%
df["address"].value_counts()
plt.pie(df["address"].value_counts().values, labels=df["address"].value_counts().index, autopct="%d%%")
plt.title('지역에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'address',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('지역에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'address',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('지역에 따른 과목별 전체학생수 분포')
plt.show()


df_by_group = df.groupby(['address'])['G1'].mean().reset_index()
sns.barplot(x='address', y='G1', data=df_by_group)
plt.title('지역에 따른 G1 평균 성적 분포')
plt.show()
ax = sns.violinplot(data=df, x="address", y="G1"),sns.barplot(x='address', y='G1', data=df_by_group, alpha = 0.5)
plt.title('지역에 따른 G1성적 분포')
plt.show()

df_by_group = df.groupby(['address'])['G2'].mean().reset_index()
sns.barplot(x='address', y='G2', data=df_by_group)
plt.title('지역에 따른 G2 평균 성적 분포')
plt.show()
ax = sns.violinplot(data=df, x="address", y="G2"),sns.barplot(x='address', y='G2', data=df_by_group, alpha = 0.5)
plt.title('지역에 따른 G2성적 분포')
plt.show()

# %% [markdown]
# # 15. higher

# %%
df["higher"].value_counts()
plt.pie(df["higher"].value_counts().values, labels=df["higher"].value_counts().index, autopct="%d%%")
plt.title('상급학교 진학희망 여부에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'higher',data = df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('상급학교 진학희망 여부에 따른 전체학생수 분포')
plt.show()

ax = sns.countplot(x = 'higher',data = df,hue = 'subject')
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
containers1 = ax.containers[1]
ax.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='center')
plt.title('상급학교 진학희망 여부에 따른 과목별 전체학생수 분포')
plt.show()


ax = sns.violinplot(data=df, x="higher", y="G1")
plt.title('상급학교 진학희망 여부에 따른 G1성적 분포')
plt.show()

ax = sns.violinplot(data=df, x="higher", y="G2")
plt.title('상급학교 진학희망 여부에 따른 G2성적 분포')
plt.show()

sns.scatterplot(data=df, x="G1", y="G2", hue="higher")
plt.title('상급학교 진학희망 여부에 따른 G1,G2성적 분포')
plt.show()

# %%
df2=pd.get_dummies(df)
df2['mean'] = (df['G1']+df['G2'])/2
df2
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 644   19     2     3           1          3         1       5         4
# 645   18     3     1           1          2         0       4         3
# 646   18     1     1           2          2         0       1         1
# 647   17     3     1           2          1         0       2         4
# 648   18     3     2           3          1         0       4         4
#
#      goout  Dalc  ...  nursery_yes  higher_no  higher_yes  internet_no  \
# ...

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df2.corr()[['mean']].sort_values(by='mean',ascending=False), vmin=-1, vmax=1,annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with mean', fontdict={'fontsize':18}, pad=16);


plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df2.corr().abs()[['mean']].sort_values(by='mean',ascending=False), vmin=-1, vmax=1,annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with mean (abs)', fontdict={'fontsize':18}, pad=16);
